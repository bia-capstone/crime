# %%
import pandas as pd, numpy as np
import crime as cr
cr.load('county_population', full=True).head(3)
# Out:
#   county  fipscode    year  age  malepopulation  femalepopulation  \
# 0  Adams       1.0  1990.0  0.0          2354.0            2404.0
# 1  Adams       1.0  1990.0  1.0          2345.0            2375.0
# 2  Adams       1.0  1990.0  2.0          2413.0            2219.0
#
#    totalpopulation
# 0           4758.0
# 1           4720.0
# 2           4632.0

# %% [markdown]
# > The reason this dataset has nearly 400,000 rows is because<br>it gives stats on EACH INDIVIDUAL AGE, 0-90, so we have to<br>aggregate it ourselves. (number of rows = counties * years * 90).<br>It also has a 60 year time range (1990-2050)

# %%
df = cr.df('county_population')
df.county = df.county.str.upper()
df['age_range'] = "over18"
df.loc[df.age <= 18, 'age_range'] = 'under19'
df.insert(2, 'age_range', df.pop('age_range'))

df = df.drop(
        columns=['age', 'fipscode']
    ).rename(columns={
        'malepopulation': 'male',
        'femalepopulation': 'female',
        'totalpopulation': 'total',
    }).groupby([
        'year', 'county', 'age_range',
    ]).sum().reset_index()

dfm = df
dfm
# Out:
#         year      county age_range      male    female     total
# 0     1990.0       ADAMS    over18   90383.0   94282.0  184665.0
# 1     1990.0       ADAMS   under19   41519.0   39525.0   81044.0
# 2     1990.0     ALAMOSA    over18    4488.0    4823.0    9311.0
# 3     1990.0     ALAMOSA   under19    2189.0    2117.0    4306.0
# 4     1990.0    ARAPAHOE    over18  134481.0  146820.0  281301.0
# ...      ...         ...       ...       ...       ...       ...
# 7803  2050.0  WASHINGTON   under19     353.0     334.0     686.0
# 7804  2050.0        WELD    over18  237224.0  236964.0  474189.0
# 7805  2050.0        WELD   under19   74010.0   71425.0  145435.0
# 7806  2050.0        YUMA    over18    3462.0    3572.0    7031.0
# 7807  2050.0        YUMA   under19    1446.0    1383.0    2826.0
#
# [7808 rows x 6 columns]

# %%
df = dfm.copy()

df = df.pivot(index=['year', 'county'], columns='age_range', values=['male', 'female', 'total']).reset_index()
df.columns = df.columns.droplevel()
df.columns.name = None
df.columns = ['year', 'county', 'over18_male', 'under19_male', 'over18_female', 'under19_female', 'over18', 'under19']

df['total'] = df.under19 + df.over18
df['male'] = df.under19_male + df.over18_male
df['female'] = df.under19_female + df.over18_female

df = df[['year', 'county', 'total', 'male', 'female', 'over18', 'under19', 'under19_male', 'under19_female', 'over18_male', 'over18_female']]
df
# Out:
#         year      county     total      male    female    over18   under19  \
# 0     1990.0       ADAMS  265709.0  131902.0  133807.0  184665.0   81044.0
# 1     1990.0     ALAMOSA   13617.0    6677.0    6940.0    9311.0    4306.0
# 2     1990.0    ARAPAHOE  393289.0  191722.0  201567.0  281301.0  111988.0
# 3     1990.0   ARCHULETA    5352.0    2725.0    2627.0    3709.0    1643.0
# 4     1990.0        BACA    4556.0    2244.0    2312.0    3360.0    1196.0
# ...      ...         ...       ...       ...       ...       ...       ...
# 3899  2050.0      SUMMIT   37255.0   19212.0   18048.0   32286.0    4969.0
# 3900  2050.0      TELLER   29192.0   14505.0   14698.0   24411.0    4781.0
# 3901  2050.0  WASHINGTON    4277.0    2201.0    2076.0    3591.0     686.0
# 3902  2050.0        WELD  619624.0  311234.0  308389.0  474189.0  145435.0
# 3903  2050.0        YUMA    9857.0    4908.0    4955.0    7031.0    2826.0
#
#       under19_male  under19_female  over18_male  over18_female
# ...

# %%
df.to_csv('output/county_population.csv')
