# %% [markdown]
# # Education data prep **Part 1**
#
# ### Standardizing county names, and general cleaning/refactoring
#
# - We have 3 education datasets:
#   - graduation rates
#   - student mobility
#   - student mobility by demographics
#
# Fortunately, just ONE of them (grad rate) has a county column. Using the district column present in all 3 datasets, we will merge the county column with the other two datasets

# %%
import crime as cr
import pandas as pd
cr.load('dist_grad_rate', full=True)
cr.load('dist_student_mobility', full=True)
_ = cr.load('dist_mobility_demographics', full=True)

# %% [markdown]
# ## Get County Names

# %%
df = cr.df('dist_grad_rate')[['organization_name', 'county_name']]
df.loc[df.organization_name == 'STATE TOTAL', 'county_name'] = 'STATE TOTAL'
df.loc[df.organization_name == 'CHARTER SCHOOL INSTITUTE', 'county_name'] = 'DENVER'

df.loc[df.organization_name == 'MOUNTAIN BOCES', 'county_name'] = 'CHAFFEE'
df.loc[df.organization_name == 'CENTENNIAL BOCES', 'county_name'] = 'WELD'
df.loc[df.organization_name == 'SAN JUAN BOCES', 'county_name'] = 'LA PLATA'
df.loc[df.organization_name == 'EXPEDITIONARY BOCES', 'county_name'] = 'DENVER'

county = df.copy()
county
# Out:
#               organization_name  county_name
# 0                   STATE TOTAL  STATE TOTAL
# 1                    MAPLETON 1        ADAMS
# 2    ADAMS 12 FIVE STAR SCHOOLS        ADAMS
# 3               ADAMS COUNTY 14        ADAMS
# 4                  BRIGHTON 27J        ADAMS
# ..                          ...          ...
# 180              MOUNTAIN BOCES      CHAFFEE
# 181            CENTENNIAL BOCES         WELD
# 182              SAN JUAN BOCES     LA PLATA
# 183         EXPEDITIONARY BOCES       DENVER
# 184                 STATE TOTAL  STATE TOTAL
#
# [185 rows x 2 columns]

# %% [markdown]
# ### Do the stuff
# 1. Merge county column
# 2. Refactor county and bring to front.
# 3. Drop unneeded columns
# 4. Drop duplicates (for some reason the 'STATE TOTAL' row is duplicated 2-4 times on some of the datasets. Weird.)
# 5. Repeat for the other two datasets

# %%
df = cr.df('dist_student_mobility')
df = county.merge(df, how='left')
df = df.rename(columns={'organization_name': 'school_dist'})
df.insert(0, 'county', df.pop('county_name'))
df = df.drop(columns=['category', 'school_year', 'org_code'])
df = df.drop_duplicates()
df.to_csv('output/dist_mobility_rate.csv')
df
# Out:
#           county                 school_dist total_pupil_count_all_students  \
# 0    STATE TOTAL                 STATE TOTAL                         939283
# 1          ADAMS                  MAPLETON 1                           9037
# 2          ADAMS  ADAMS 12 FIVE STAR SCHOOLS                          49889
# 3          ADAMS             ADAMS COUNTY 14                           8265
# 4          ADAMS                BRIGHTON 27J                          17152
# ..           ...                         ...                            ...
# 179       DENVER    CHARTER SCHOOL INSTITUTE                          12020
# 180      CHAFFEE              MOUNTAIN BOCES                            184
# 181         WELD            CENTENNIAL BOCES                            146
# 182     LA PLATA              SAN JUAN BOCES                             84
# 183       DENVER         EXPEDITIONARY BOCES                            402
#
#     total_stable_pupil_count_all_students total_stability_rate_all_students  \
# 0                                  705064                              75.1
# 1                                    5077                              56.2
# 2                                   34283                              68.7
# 3                                    5510                              66.7
# 4                                   13109                              76.4
# ..                                    ...                               ...
# 179                                  5323                              44.3
# 180                                    76                              41.3
# 181                                     0                                 0
# 182                                     0                                 0
# 183                                   302                              75.1
#
#     total_mobile_student_count_all_students  \
# 0                                    231706
# 1                                      3919
# 2                                     15424
# 3                                      3038
# 4                                      3982
# ..                                      ...
# 179                                    6660
# 180                                     113
# 181                                     146
# 182                                      84
# 183                                     100
#
#     total_student_mobility_rate_all_students  \
# 0                                       24.7
# 1                                       43.4
# 2                                       30.9
# 3                                       36.8
# 4                                       23.2
# ..                                       ...
# 179                                     55.4
# 180                                     61.4
# 181                                      100
# 182                                      100
# 183                                     24.9
#
#     total_instances_of_mobility_all_students  \
# 0                                     253577
# 1                                       4133
# 2                                      16854
# 3                                       3397
# 4                                       4294
# ..                                       ...
# 179                                     6800
# 180                                      116
# 181                                      146
# 182                                       84
# 183                                      101
#
#     total_mobility_incidence_rate_all_students  \
# 0                                           27
# 1                                         45.7
# 2                                         33.8
# 3                                         41.1
# 4                                           25
# ..                                         ...
# 179                                       56.6
# 180                                         63
# 181                                        100
# 182                                        100
# 183                                       25.1
#
#     students_with_disabilities_pupil_count  ...  \
# 0                                    84121  ...
# 1                                      735  ...
# 2                                     4339  ...
# 3                                      876  ...
# 4                                     1405  ...
# ..                                     ...  ...
# 179                                    708  ...
# 180                                     36  ...
# 181                                      2  ...
# 182                                      5  ...
# 183                                     40  ...
#
#     homeless_student_mobility_rate homeless_instances_of_mobility  \
# 0                             45.3                          11558
# 1                             32.7                             79
# 2                             57.2                            481
# 3                             49.7                            529
# 4                             67.9                            287
# ..                             ...                            ...
# 179                           72.3                             69
# 180                           57.1                             21
# 181                              0                              0
# 182                              0                              0
# 183                              0                              0
#
#     homeless_mobility_incidence_rate gifted_talented_pupil_count  \
# 0                               54.2                       73344
# 1                               36.9                         250
# 2                               68.2                        3590
# 3                               59.7                         377
# 4                               74.9                         703
# ..                               ...                         ...
# 179                             73.4                         343
# 180                               60                           1
# 181                                0                           0
# 182                                0                           3
# 183                                0                           0
#
#     gifted_talented_stable_student_count gifted_talented_stability_rate  \
# 0                                  66620                           90.8
# 1                                    205                             82
# 2                                   3225                           89.8
# 3                                    317                           84.1
# 4                                    630                           89.6
# ..                                   ...                            ...
# 179                                  172                           50.1
# 180                                    1                            100
# 181                                    0                              0
# 182                                    0                              0
# 183                                    0                              0
#
#     gifted_talented_mobile_student_count  \
# 0                                   6641
# 1                                     44
# 2                                    361
# 3                                     75
# 4                                     70
# ..                                   ...
# 179                                  169
# 180                                    0
# 181                                    0
# 182                                    3
# 183                                    0
#
#     gifted_talented_student_mobility_rate  \
# 0                                     9.1
# 1                                    17.6
# 2                                    10.1
# 3                                    19.9
# 4                                      10
# ..                                    ...
# 179                                  49.3
# 180                                     0
# 181                                     0
# 182                                   100
# 183                                     0
#
#     gifted_talented_instances_of_mobility  \
# 0                                    7366
# 1                                      47
# 2                                     404
# 3                                      89
# 4                                      76
# ..                                    ...
# 179                                   174
# 180                                     1
# 181                                     0
# 182                                     3
# 183                                     0
#
#     gifted_talented_mobility_incidence_rate
# 0                                        10
# 1                                      18.8
# 2                                      11.3
# 3                                      23.6
# 4                                      10.8
# ..                                      ...
# 179                                    50.7
# 180                                     100
# 181                                       0
# 182                                     100
# 183                                       0
#
# [184 rows x 58 columns]

# %%
df = cr.df('dist_grad_rate')
df = df.drop(columns='county_name')
df = county.merge(df, how='left')
df = df.rename(columns={'organization_name': 'school_dist'})
df.insert(0, 'county', df.pop('county_name'))
df = df.drop(columns=['organization_code'])
df = df.drop_duplicates()
df.to_csv('output/dist_grad_rate.csv')
df
# Out:
#           county                 school_dist  \
# 0    STATE TOTAL                 STATE TOTAL
# 2          ADAMS                  MAPLETON 1
# 3          ADAMS  ADAMS 12 FIVE STAR SCHOOLS
# 4          ADAMS             ADAMS COUNTY 14
# 5          ADAMS                BRIGHTON 27J
# ..           ...                         ...
# 180       DENVER    CHARTER SCHOOL INSTITUTE
# 181      CHAFFEE              MOUNTAIN BOCES
# 182         WELD            CENTENNIAL BOCES
# 183     LA PLATA              SAN JUAN BOCES
# 184       DENVER         EXPEDITIONARY BOCES
#
#     students_with_disabilities_final_grad_base  \
# 0                                         5775
# 2                                           49
# 3                                          250
# 4                                           59
# 5                                           66
# ..                                         ...
# 180                                        111
# 181                                         19
# 182                                          6
# 183                                          1
# 184                                          2
#
#     students_with_disabilities_graduates_total  \
# 0                                         3099
# 2                                           18
# 3                                          118
# 4                                           32
# 5                                           33
# ..                                         ...
# 180                                         16
# 181                                         14
# 182                                          1
# 183                                          0
# 184                                          2
#
#     students_with_disabilities_graduation_rate  \
# 0                                         53.7
# 2                                         36.7
# 3                                         47.2
# 4                                         54.2
# 5                                         50.0
# ..                                         ...
# 180                                       14.4
# 181                                       73.7
# 182                                       16.7
# 183                                        0.0
# 184                                      100.0
#
#     students_with_disabilities_completers_total  \
# 0                                          3222
# 2                                            19
# 3                                           127
# 4                                            32
# 5                                            35
# ..                                          ...
# 180                                          17
# 181                                          16
# 182                                           1
# 183                                           0
# 184                                           2
#
#     students_with_disabilities_completion_rate  \
# 0                                         55.8
# 2                                         38.8
# 3                                         50.8
# 4                                         54.2
# 5                                         53.0
# ..                                         ...
# 180                                       15.3
# 181                                       84.2
# 182                                       16.7
# 183                                        0.0
# 184                                      100.0
#
#     limited_english_proficient_final_grad_base  \
# 0                                         6171
# 2                                          219
# 3                                          379
# 4                                          170
# 5                                          110
# ..                                         ...
# 180                                        141
# 181                                         17
# 182                                          4
# 183                                          1
# 184                                          0
#
#     limited_english_proficient_graduates_total  \
# 0                                         3289
# 2                                           73
# 3                                          257
# 4                                           86
# 5                                           63
# ..                                         ...
# 180                                         31
# 181                                         10
# 182                                          1
# 183                                          1
# 184                                          0
#
#     limited_english_proficient_graduation_rate  ... homeless_final_grad_base  \
# 0                                         53.3  ...                     2394
# 2                                         33.3  ...                       41
# 3                                         67.8  ...                      106
# 4                                         50.6  ...                       99
# 5                                         57.3  ...                       41
# ..                                         ...  ...                      ...
# 180                                       22.0  ...                      121
# 181                                       58.8  ...                       14
# 182                                       25.0  ...                        1
# 183                                      100.0  ...                        0
# 184                                        0.0  ...                        0
#
#     homeless_graduates_total homeless_graduation_rate  \
# 0                       1175                     49.1
# 2                         12                     29.3
# 3                         62                     58.5
# 4                         52                     52.5
# 5                         21                     51.2
# ..                       ...                      ...
# 180                       11                      9.1
# 181                        9                     64.3
# 182                        0                      0.0
# 183                        0                      0.0
# 184                        0                      0.0
#
#     homeless_completers_total homeless_completion_rate  \
# 0                        1262                     52.7
# 2                          16                     39.0
# 3                          65                     61.3
# 4                          57                     57.6
# 5                          21                     51.2
# ..                        ...                      ...
# 180                        11                      9.1
# 181                        10                     71.4
# 182                         0                      0.0
# 183                         0                      0.0
# 184                         0                      0.0
#
#     gifted_talented_final_grad_base gifted_talented_graduates_total  \
# 0                              6604                            6048
# 2                                44                              27
# 3                               227                             201
# 4                                30                              27
# 5                                63                              51
# ..                              ...                             ...
# 180                              47                              23
# 181                               2                               1
# 182                               0                               0
# 183                               1                               0
# 184                               0                               0
#
#     gifted_talented_graduation_rate gifted_talented_completers_total  \
# 0                              91.6                             6156
# 2                              61.4                               27
# 3                              88.5                              208
# 4                              90.0                               27
# 5                              81.0                               52
# ..                              ...                              ...
# 180                            48.9                               27
# 181                            50.0                                1
# 182                             0.0                                0
# 183                             0.0                                1
# 184                             0.0                                0
#
#     gifted_talented_completion_rate
# 0                              93.2
# 2                              61.4
# 3                              91.6
# 4                              90.0
# 5                              82.5
# ..                              ...
# 180                            57.4
# 181                            50.0
# 182                             0.0
# 183                           100.0
# 184                             0.0
#
# [184 rows x 37 columns]

# %%
df = cr.df('dist_mobility_demographics')
df = county.merge(df, how='left')
df = df.rename(columns={'organization_name': 'school_dist'})
df.insert(0, 'county', df.pop('county_name'))
df = df.drop(columns=['category', 'school_year', 'org_code'])
df = df.drop_duplicates()
df.to_csv('output/dist_mobility_rate_demographics.csv')
df
# Out:
#           county                 school_dist total_pupil_count  \
# 0    STATE TOTAL                 STATE TOTAL            939283
# 2          ADAMS                  MAPLETON 1              9037
# 3          ADAMS  ADAMS 12 FIVE STAR SCHOOLS             49889
# 4          ADAMS             ADAMS COUNTY 14              8265
# 5          ADAMS                BRIGHTON 27J             17152
# ..           ...                         ...               ...
# 180       DENVER    CHARTER SCHOOL INSTITUTE             12020
# 181      CHAFFEE              MOUNTAIN BOCES               184
# 182         WELD            CENTENNIAL BOCES               146
# 183     LA PLATA              SAN JUAN BOCES                84
# 184       DENVER         EXPEDITIONARY BOCES               402
#
#     total_stable_student_count total_stability_rate  \
# 0                       705064                 75.1
# 2                         5077                 56.2
# 3                        34283                 68.7
# 4                         5510                 66.7
# 5                        13109                 76.4
# ..                         ...                  ...
# 180                       5323                 44.3
# 181                         76                 41.3
# 182                          0                    0
# 183                          0                    0
# 184                        302                 75.1
#
#     total_mobile_student_count total_student_mobility_rate  \
# 0                       231706                        24.7
# 2                         3919                        43.4
# 3                        15424                        30.9
# 4                         3038                        36.8
# 5                         3982                        23.2
# ..                         ...                         ...
# 180                       6660                        55.4
# 181                        113                        61.4
# 182                        146                         100
# 183                         84                         100
# 184                        100                        24.9
#
#     total_instances_of_mobility total_mobility_incidence_rate  \
# 0                        253577                            27
# 2                          4133                          45.7
# 3                         16854                          33.8
# 4                          3397                          41.1
# 5                          4294                            25
# ..                          ...                           ...
# 180                        6800                          56.6
# 181                         116                            63
# 182                         146                           100
# 183                          84                           100
# 184                         101                          25.1
#
#     total_female_pupil_count  ...  \
# 0                     458512  ...
# 2                       4450  ...
# 3                      24340  ...
# 4                       3966  ...
# 5                       8452  ...
# ..                       ...  ...
# 180                     6311  ...
# 181                      103  ...
# 182                       64  ...
# 183                       36  ...
# 184                      184  ...
#
#     total_native_hawaiian_or_other_pacific_islander_student_mobility_rate  \
# 0                                                 34.8
# 2                                                 70.8
# 3                                                 45.3
# 4                                                    0
# 5                                                 30.6
# ..                                                 ...
# 180                                               51.9
# 181                                                  0
# 182                                                  0
# 183                                                  0
# 184                                                  0
#
#     total_native_hawaiian_or_other_pacific_islander_instances_of_mobility  \
# 0                                                  840
# 2                                                   17
# 3                                                   42
# 4                                                    0
# 5                                                   12
# ..                                                 ...
# 180                                                 15
# 181                                                  0
# 182                                                  0
# 183                                                  0
# 184                                                  0
#
#     total_native_hawaiian_or_other_pacific_islander_mobility_incidence_rate  \
# 0                                                   38
# 2                                                 70.8
# 3                                                 48.8
# 4                                                    0
# 5                                                 33.3
# ..                                                 ...
# 180                                               55.6
# 181                                                  0
# 182                                                  0
# 183                                                  0
# 184                                                  0
#
#     total_two_or_more_races_pupil_count  \
# 0                                 29329
# 2                                   219
# 3                                   662
# 4                                    55
# 5                                   423
# ..                                  ...
# 180                                 187
# 181                                   0
# 182                                   0
# 183                                   3
# 184                                  26
#
#     total_two_or_more_races_stable_student_count  \
# 0                                          21501
# 2                                            129
# 3                                            455
# 4                                             28
# 5                                            304
# ..                                           ...
# 180                                           92
# 181                                            0
# 182                                            0
# 183                                            0
# 184                                           16
#
#     total_two_or_more_races_stability_rate  \
# 0                                     73.3
# 2                                     58.9
# 3                                     68.7
# 4                                     50.9
# 5                                     71.9
# ..                                     ...
# 180                                   49.2
# 181                                      0
# 182                                      0
# 183                                      0
# 184                                   61.5
#
#     total_two_or_more_races_mobile_student_count  \
# 0                                           7718
# 2                                             90
# 3                                            203
# 4                                             26
# 5                                            117
# ..                                           ...
# 180                                           94
# 181                                            0
# 182                                            0
# 183                                            3
# 184                                           10
#
#     total_two_or_more_races_student_mobility_rate  \
# 0                                            26.3
# 2                                            41.1
# 3                                            30.7
# 4                                            47.3
# 5                                            27.7
# ..                                            ...
# 180                                          50.3
# 181                                             0
# 182                                             0
# 183                                           100
# 184                                          38.5
#
#     total_two_or_more_races_instances_of_mobility  \
# 0                                            8433
# 2                                              91
# 3                                             222
# 4                                              28
# 5                                             127
# ..                                            ...
# 180                                            96
# 181                                             0
# 182                                             0
# 183                                             3
# 184                                            10
#
#     total_two_or_more_races_mobility_incidence_rate
# 0                                              28.8
# 2                                              41.6
# 3                                              33.5
# 4                                              50.9
# 5                                                30
# ..                                              ...
# 180                                            51.3
# 181                                               0
# 182                                               0
# 183                                             100
# 184                                            38.5
#
# [184 rows x 72 columns]
