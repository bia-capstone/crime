# %%
import crime as cr

cr.help()

# %%
cr.load('marijuana_arrests', full=True)
# Out:
#       arrestyear county            agency     agegroup  gender  \
# 0         2012.0  Adams  Commerce City PD  21 or older  Female
# 1         2012.0  Adams  Commerce City PD  21 or older    Male
# 2         2012.0  Adams  Commerce City PD  21 or older    Male
# 3         2012.0  Adams  Commerce City PD  21 or older    Male
# 4         2012.0  Adams  Commerce City PD  21 or older    Male
# ...          ...    ...               ...          ...     ...
# 7692      2017.0   Weld      Severance PD     18 to 20  Female
# 7693      2017.0   Weld    Weld County SO     18 to 20  Female
# 7694      2017.0   Weld    Weld County SO     18 to 20  Female
# 7695      2017.0   Weld        Windsor PD     Under 18    Male
# 7696      2017.0   Weld        Windsor PD  21 or older    Male
#
#               racecode      nciccode  numberofarrests
# 0            Hispianic  MJPossession              6.0
# 1     African American  MJPossession              5.0
# ...

# %%
cr.load('marijuana_offenses', full=True)
# Out:
#       incidentyear     county            agency      nciccode  \
# 0           2015.0      Adams  Commerce City PD  MJPossession
# 1           2012.0  Jefferson       Lakewood PD     MJUnknown
# 2           2016.0       Weld        Windsor PD     MJUnknown
# 3           2012.0    Douglas      Lone Tree PD  MJPossession
# 4           2012.0      Adams   Adams County SO  MJPossession
# ...            ...        ...               ...           ...
# 6785        2017.0       Weld        LaSalle PD  MJProduction
# 6786        2017.0       Weld    Weld County SO  MJPossession
# 6787        2017.0       Weld    Weld County SO       MJSales
# 6788        2017.0       Weld        Windsor PD  MJPossession
# 6789        2017.0       Weld        Windsor PD  MJPossession
#
#                                 location                       locationgroup  \
# 0                          Other/Unknown                               Other
# ...

# %%
df = cr.columns('county_demographics')

# %%
cr.columns('crime_16_19')

# %%
cr.load('crime_rates', full=True)
